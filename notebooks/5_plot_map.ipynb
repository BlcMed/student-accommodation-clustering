# %% [markdown]
# Import libraries

# %%
import sys
sys.path.append("../src")
from visualization import map_plotter
import pandas as pd
import json

# %% [markdown]
# Get the Mercyhurst University coordinates and load the data

# %%
with open("../data/raw/mercyhurst_coordinates.txt") as file:
    ll = json.loads(file.read())['ll']
    file.close()
location = eval(ll)
df_venues = pd.read_csv('../data/processed/venues_with_clusters.csv')
df_venues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        50 non-null     float64
#  1   longitude       50 non-null     float64
#  2   fsq_id          50 non-null     object
#  3   address         50 non-null     object
#  4   country         50 non-null     object
#  5   postal_code     50 non-null     object
#  6   region          50 non-null     object
#  7   restaurants     50 non-null     int64
#  8   groceries       50 non-null     int64
#  9   cluster         50 non-null     int64
#  10  recomended for  50 non-null     object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 4.4+ KB

# %%
mp=map_plotter.MapPlotter(location)
mp.plot_map(df_venues[['latitude','longitude']], df_venues['cluster'],df_venues[['recomended for','restaurants','groceries','region']])
mp.save_map()
mp.map
# Out:
# c:\Users\HP\OneDrive\Desktop\student-accommodation-clustering\notebooks\../src\visualization\map_plotter.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lat=df_loc.iloc[ind][0]
# c:\Users\HP\OneDrive\Desktop\student-accommodation-clustering\notebooks\../src\visualization\map_plotter.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   long=df_loc.iloc[ind][1]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51dd84c97bac5cd5cb8f475565d57753 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51dd84c97bac5cd5cb8f475565d57753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51dd84c97bac5cd5cb8f475565d57753 = L.map(
#                 &quot;map_51dd84c97bac5cd5cb8f475565d57753&quot;,
#                 {
#                     center: [42.105724, -80.053591],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0df965c2d4f0544fa8d3daacc78a31fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0df965c2d4f0544fa8d3daacc78a31fe.addTo(map_51dd84c97bac5cd5cb8f475565d57753);
#
#
#             var circle_marker_1ed212024583975f5c38abc2c08a52ea = L.circleMarker(
#                 [42.12344, -80.077909],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8D1FD9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8D1FD9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51dd84c97bac5cd5cb8f475565d57753);
#
#
#         var popup_759475d8d35698f90afef3e453b0d13a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa3ef4091f067a32d751d8d786a9de86 = $(`&lt;div id=&quot;html_fa3ef4091f067a32d751d8d786a9de86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;recomended for: Minimal dining restaurants: 42 groceries: 6 region: PA&lt;/div&gt;`)[0];
#                 popup_759475d8d35698f90afef3e453b0d13a.setContent(html_fa3ef4091f067a32d751d8d786a9de86);
#
#
#
#         circle_marker_1ed212024583975f5c38abc2c08a52ea.bindPopup(popup_759475d8d35698f90afef3e453b0d13a)
#         ;
#
#
#
#
#             var circle_marker_59e5e5350eb46f6b0f771e646c021eef = L.circleMarker(
#                 [42.126495, -80.087438],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8D1FD9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#8D1FD9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51dd84c97bac5cd5cb8f475565d57753);
#
#
#         var popup_d86eed7021e606be4ee15593d5eb432b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adffd75c40b8bc91c642dd93962f86aa = $(`&lt;div id=&quot;html_adffd75c40b8bc91c642dd93962f86aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;recomended for: Minimal dining restaurants: 50 groceries: 5 region: PA&lt;/div&gt;`)[0];
#                 popup_d86eed7021e606be4ee15593d5eb432b.setContent(html_adffd75c40b8bc91c642dd93962f86aa);
#
#
#
#         circle_marker_59e5e5350eb46f6b0f771e646c021eef.bindPopup(popup_d86eed7021e606be4ee15593d5eb432b)
#         ;
#
#
#
#
#             var circle_marker_789b8ad4212aaf285e6bb4cc5a41a141 = L.circleMarker(
#                 [42.067218, -80.08973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#123002&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#123002&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51dd84c97bac5cd5cb8f475565d57753);
#
#
#         var popup_cfa43ccce59ace11dbe0c1fc0773d21c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16376af8f69cc4818be9b57d06afaf77 = $(`&lt;div id=&quot;html_16376af8f69cc4818be9b57d06afaf77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;recomended for: Frequent dining restaurants: 26 groceries: 3 region: PA&lt;/div&gt;`)[0];
#                 popup_cfa43ccce59ace11dbe0c1fc0773d21c.setContent(html_16376af8f69cc4818be9b57d06afaf77);
#
#
#
#         circle_marker_789b8ad4212aaf285e6bb4cc5a41a141.bindPopup(popup_cfa43ccce59ace11dbe0c1fc0773d21c)
#         ;
#
#
#
#
#             var circle_marker_43f17609cd79cd1f262e7edec877ef61 = L.circleMarker(
#                 [42.109142, -79.287287],
#                 {&quot;bubblingMouseEvents&quot;:
